# %%
# !{sys.executable} -m pip install pandas numpy matplotlib yfinance lxml pyarrow fastparquet requests
# Out:
# zsh:1: parse error near `-m'

# %%
import sys
sys.path.append("/Users/prayag/Documents/AlphaFactorPipeline")

from data_loader import download_prices, load_prices, compute_returns

# %%
import sys

import os
os.chdir("/Users/prayag/Documents/AlphaFactorPipeline")

prices = load_prices()
print(prices.shape)        # should be (days, n_tickers)
print(prices.head())       # first 5 rows
prices["AAPL"].plot()      # Apple price chart
# Out:
# (252, 50)
# Ticker               A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2024-01-02  136.120499  183.562195  146.569794  134.479996  104.509537
# 2024-01-03  128.674347  182.187759  147.156723  133.419998  104.195595
# 2024-01-04  128.517395  179.873947  148.073822  133.720001  105.584610
# 2024-01-05  128.085709  179.152100  148.697433  135.979996  105.413361
# 2024-01-08  130.852264  183.483078  148.046280  140.080002  106.935570
#
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...  \
# Date                                                                  ...
# 2024-01-02  71.840385  333.794586  580.070007  186.168289  66.643600  ...
# 2024-01-03  73.162132  325.135132  571.789978  181.725189  66.982506  ...
# 2024-01-04  73.666107  324.336517  567.049988  178.945831  65.718506  ...
# 2024-01-05  73.038513  323.884308  564.599976  179.407455  64.857521  ...
# 2024-01-08  73.333298  327.473175  580.549988  181.744415  65.086510  ...
#
# ...
